# %%
# %load_ext autoreload
# %autoreload 2

# %%
from molz import ZScorer

scorer = ZScorer('testdata_5k.csv', fp_bits=4096, fp_rad=3)
scorer.score_fragments('penalised_logp', [12, 30])
# Out:
# ...
# Computing fragment z-scores: 100%|██████████| 4096/4096 [00:10<00:00, 397.86it/s]

# %%
fig = scorer.barplot(k=35, save_to='example_penalised_logp.png', figsize=(20, 3))

# %%
scorer.draw_fragment(1483)
